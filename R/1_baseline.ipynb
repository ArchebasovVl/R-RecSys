# %%
source("./scripts/utils.r")

df <- read.csv("./data/fashion_products.csv")

df[, "User.ID"] <- as.character(df[, "User.ID"])
df[, "Product.ID"] <- as.character(df[, "Product.ID"])

sapply(df, class)
cat("\n")
head(df)
# Out:
#      User.ID   Product.ID Product.Name        Brand     Category        Price
#  "character"  "character"  "character"  "character"  "character"    "integer"
#       Rating        Color         Size
#    "numeric"  "character"  "character"
#   User.ID Product.ID Product.Name Brand  Category        Price Rating   Color
# 1 19      1          Dress        Adidas Men's Fashion   40    1.043159 Black
# 2 97      2          Shoes        H&M    Women's Fashion 82    4.026416 Black
# 3 25      3          Dress        Adidas Women's Fashion 44    3.337938 Yellow
# 4 57      4          Shoes        Zara   Men's Fashion   23    1.049523 White
# 5 79      5          T-shirt      Adidas Men's Fashion   79    4.302773 Black
# 6 98      6          Dress        Adidas Men's Fashion   47    1.379566 Yellow
#   Size
# 1 XL
# 2 L
# 3 XL
# 4 S
# 5 M
# 6 L

# %%
result <- create_user_item_matrix(df, "User.ID", "Product.ID", "Rating")
user_rating_matrix <- result[1][[1]]
user_map <- result[2][[1]]
item_map <- result[3][[1]]

print(dim(user_rating_matrix))
# Out:
# [1]  100 1000

# %%
model <- fit_baseline(user_rating_matrix)
pred <- predict_baseline(model, user_rating_matrix, '1', user_map)
best_ind <- choose_k_best(pred, 3)

print("best products ids for the first user:")
for (i in best_ind) {
    cat("id:", item_map[[as.character(i)]], "\tevaluated rating:", pred[i], "\n")
}
# Out:
# [1] "best products ids for the first user:"
# id: 986 	evaluated rating: 4.614653
# id: 964 	evaluated rating: 4.541802
# id: 879 	evaluated rating: 4.301462
